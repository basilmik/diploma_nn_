# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
import random
import torch
from torch import nn
import torch.nn.functional as F

# %%
# Define model
class DQN(nn.Module):
    def __init__(self, in_states, h1_nodes, out_actions):
        super().__init__()

        # Define network layers
        self.fc1 = nn.Linear(in_states, h1_nodes)   # first fully connected layer
        self.out = nn.Linear(h1_nodes, out_actions) # ouptut layer w

    def forward(self, x):
        x = F.relu(self.fc1(x)) # Apply rectified linear unit (ReLU) activation
        x = self.out(x)         # Calculate output
        return x

# Define memory for Experience Replay
class ReplayMemory():
    def __init__(self, maxlen):
        self.memory = deque([], maxlen=maxlen)

    def append(self, transition):
        self.memory.append(transition)

    def sample(self, sample_size):
        return random.sample(self.memory, sample_size)

    def __len__(self):
        return len(self.memory)

# MountainCar Deep Q-Learning
class MountainCarDQL():
    # Hyperparameters (adjustable)
    learning_rate_a = 0.001         # learning rate (alpha)
    discount_factor_g = 0.95         # discount rate (gamma)
    network_sync_rate = 25000          # number of steps the agent takes before syncing the policy and target network
    replay_memory_size = 100000       # size of replay memory
    mini_batch_size = 64            # size of the training data set sampled from the replay memory

    #num_divisions = 40

    # Neural Network
    loss_fn = nn.MSELoss()          # NN Loss function. MSE=Mean Squared Error can be swapped to something else.
    optimizer = None                # NN Optimizer. Initialize later.
 
    def plot_progress(self, rewards_per_episode, epsilon_history):
        plt.figure(1)
        plt.subplot(121) # plot on a 1 row x 2 col grid, at cell 1
        # plt.plot(sum_rewards)
        plt.plot(rewards_per_episode)

        plt.subplot(122) # plot on a 1 row x 2 col grid, at cell 2
        plt.plot(epsilon_history)

        plt.savefig('carpole_dql.png')


    def state_to_dqn_input(self, state)->torch.Tensor:
        # state_p = np.digitize(state[0], self.pos_space)
        # state_v = np.digitize(state[1], self.vel_space)
        # state_p1 = np.digitize(state[2], self.pos_space1)
        # state_v1 = np.digitize(state[3], self.vel_space1)

        #return torch.FloatTensor([state_p, state_v, state_p1, state_v1])
        return torch.FloatTensor(state)
    

    # Train the environment
    def train(self, episodes, render=False):
        # Create FrozenLake instance
        env = gym.make('CartPole-v0', render_mode='human' if render else None)
        num_states = env.observation_space.shape[0] # expecting 2: position & velocity
        num_actions = env.action_space.n

        # Divide position and velocity into segments
        #self.pos_space = np.linspace(env.observation_space.low[0], env.observation_space.high[0], self.num_divisions)    # Between -1.2 and 0.6
        #self.vel_space = np.linspace(env.observation_space.low[1], env.observation_space.high[1], self.num_divisions)    # Between -0.07 and 0.07
        #self.pos_space1 = np.linspace(env.observation_space.low[2], env.observation_space.high[2], self.num_divisions)    # Between -1.2 and 0.6
        #self.vel_space1 = np.linspace(env.observation_space.low[3], env.observation_space.high[3], self.num_divisions)
        
        epsilon = 1 # 1 = 100% random actions
        memory = ReplayMemory(self.replay_memory_size)


        policy_dqn = DQN(in_states=num_states, h1_nodes=24, out_actions=num_actions)
        target_dqn = DQN(in_states=num_states, h1_nodes=24, out_actions=num_actions)

        target_dqn.load_state_dict(policy_dqn.state_dict())

        self.optimizer = torch.optim.Adam(policy_dqn.parameters(), lr=self.learning_rate_a)

        # List to keep track of rewards collected per episode. Initialize list to 0's.
        rewards_per_episode = []

        # List to keep track of epsilon decay
        epsilon_history = []

        # Track number of steps taken. Used for syncing policy => target network.
        step_count=0
        goal_reached=False
        best_rewards=0

        for i in range(episodes):
            state = env.reset()[0]  # Initialize to state 0
            terminated = False      # True when agent falls in hole or reached goal
            truncated = False
            rewards = 0

            while(not terminated and not truncated):

                # Select action based on epsilon-greedy
                if random.random() < epsilon:
                    # select random action
                    action = env.action_space.sample()
                else:
                    # select best action
                    with torch.no_grad():
                        action = policy_dqn(self.state_to_dqn_input(state)).argmax().item()

                # Execute action
                new_state, reward, terminated, done_success,_ = env.step(action)
                
                if terminated: # mistake
                    reward = -1
                if done_success:
                    reward = 2
                    
                # Accumulate reward
                rewards += reward

                # Save experience into memory
                memory.append((state, action, new_state, reward, done_success, terminated))

                # Move to the next state
                state = new_state

                # Increment step counter
                step_count+=1

            # Keep track of the rewards collected per episode.
            rewards_per_episode.append(rewards)
            
            if(done_success):
                goal_reached = True

            # Graph training progress
            if(i!=0 and i%500==0):
                print(f'Episode {i} Epsilon {epsilon}')
                self.plot_progress(rewards_per_episode, epsilon_history)
                torch.save(policy_dqn.state_dict(), f"carpole_dql_{i}.pt")                 # Save policy

            if rewards > best_rewards:
                best_rewards = rewards
                print(f'Best rewards so far: {best_rewards}')

                

            # Check if enough experience has been collected
            if len(memory) > self.mini_batch_size:# and goal_reached:
                #print('optimize Episode ', i)
                mini_batch = memory.sample(self.mini_batch_size)
                self.optimize(mini_batch, policy_dqn, target_dqn)

                # Decay epsilon
                epsilon = max(epsilon*0.99995, 0.05)
                epsilon_history.append(epsilon)

                # Copy policy network to target network after a certain number of steps
                if step_count > self.network_sync_rate:
                    print('sync Episode ', i)
                    target_dqn.load_state_dict(policy_dqn.state_dict())
                    step_count=0
                    
                    #self.mini_batch_size +=2

        # Close environment
        env.close()
        torch.save(policy_dqn.state_dict(), "carpole_dql_last.pt")

   
    def optimize(self, mini_batch, policy_dqn, target_dqn):
        current_q_list = []
        target_q_list = []

        for state, action, new_state, reward, done_success, terminated in mini_batch:

            if done_success or terminated:
                target = torch.FloatTensor([reward])
            else:
                with torch.no_grad():
                    target = torch.FloatTensor(
                        reward + self.discount_factor_g * target_dqn(self.state_to_dqn_input(new_state)).max()
                    )

            # Get the current set of Q values
            current_q = policy_dqn(self.state_to_dqn_input(state))
            current_q_list.append(current_q)

            # Get the target set of Q values
            target_q = target_dqn(self.state_to_dqn_input(state))
            
            # Adjust the specific action to the target that was just calculated
            target_q[action] = target
            target_q_list.append(target_q)

        # Compute loss for the whole minibatch
        loss = self.loss_fn(torch.stack(current_q_list), torch.stack(target_q_list))

        # Optimize the model
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()



    # Run the environment with the learned policy
    def test(self, episodes, model_filepath):
        # Create FrozenLake instance
        env = gym.make('CartPole-v0', render_mode='human')
        num_states = env.observation_space.shape[0]
        num_actions = env.action_space.n

        # self.pos_space = np.linspace(env.observation_space.low[0], env.observation_space.high[0], self.num_divisions)    # Between -1.2 and 0.6
        # self.vel_space = np.linspace(env.observation_space.low[1], env.observation_space.high[1], self.num_divisions)    # Between -0.07 and 0.07
        # self.pos_space1 = np.linspace(env.observation_space.low[2], env.observation_space.high[2], self.num_divisions)    # Between -1.2 and 0.6
        # self.vel_space1 = np.linspace(env.observation_space.low[3], env.observation_space.high[3], self.num_divisions)

        # Load learned policy
        policy_dqn = DQN(in_states=num_states, h1_nodes=24, out_actions=num_actions)
        policy_dqn.load_state_dict(torch.load(model_filepath))
        policy_dqn.eval()    # switch model to evaluation mode

        for i in range(episodes):
            state = env.reset()[0]  # Initialize to state 0
            terminated = False      # True when agent falls in hole or reached goal
            truncated = False       # True when agent takes more than 200 actions

            # Agent navigates map until it falls into a hole (terminated), reaches goal (terminated), or has taken 200 actions (truncated).
            while(not terminated and not truncated):
                # Select best action
                with torch.no_grad():
                    action = policy_dqn(self.state_to_dqn_input(state)).argmax().item()

                # Execute action
                state,reward,terminated,truncated,_ = env.step(action)

        env.close()

# %%
mountaincar = MountainCarDQL()

# %%
mountaincar.train(40000, False)
# Out:
# Best rewards so far: 18.0
# Best rewards so far: 31.0
# Best rewards so far: 59.0
# Best rewards so far: 62.0
# Best rewards so far: 74.0
# Episode 500 Epsilon 0.9754556134657344
# Best rewards so far: 86.0
# Episode 1000 Epsilon 0.951370933929971
# sync Episode  1120
# Episode 1500 Epsilon 0.9278809219324657
# Episode 2000 Epsilon 0.9049708947168845
# Best rewards so far: 105.0
# sync Episode  2273
# Episode 2500 Epsilon 0.8826265320543847
# Episode 3000 Epsilon 0.8608338672925662
# sync Episode  3458
# Episode 3500 Epsilon 0.8395792786254197
# Episode 4000 Epsilon 0.8188494805788252
# Episode 4500 Epsilon 0.7986315157062884
# sync Episode  4711
# Best rewards so far: 108.0
# Episode 5000 Epsilon 0.7789127464897095
# Episode 5500 Epsilon 0.7596808474401222
# sync Episode  5789
# Best rewards so far: 113.0
# Episode 6000 Epsilon 0.7409237973934815
# Best rewards so far: 123.0
# Episode 6500 Epsilon 0.7226298719966712
# sync Episode  6728
# Best rewards so far: 159.0
# Episode 7000 Epsilon 0.7047876363790263
# sync Episode  7451
# Episode 7500 Epsilon 0.6873859380048193
# Episode 8000 Epsilon 0.67041389970221
# sync Episode  8036
# Episode 8500 Epsilon 0.653860912864313
# sync Episode  8549
# Best rewards so far: 227.0
# Episode 9000 Epsilon 0.637716630818154
# sync Episode  9046
# Best rewards so far: 229.0
# Episode 9500 Epsilon 0.6219709623573282
# sync Episode  9505
# sync Episode  9901
# Best rewards so far: 261.0
# Episode 10000 Epsilon 0.606614065434357
# sync Episode  10272
# Episode 10500 Epsilon 0.5916363410087786
# Best rewards so far: 447.0
# sync Episode  10640
# sync Episode  10951
# Episode 11000 Epsilon 0.5770284270471369
# sync Episode  11254
# Episode 11500 Epsilon 0.5627811926711124
# sync Episode  11548
# Best rewards so far: 525.0
# Best rewards so far: 591.0
# sync Episode  11836
# Episode 12000 Epsilon 0.5488857324501376
# sync Episode  12091
# sync Episode  12364
# Episode 12500 Epsilon 0.5353333608349451
# sync Episode  12619
# sync Episode  12870
# Episode 13000 Epsilon 0.5221156067285292
# sync Episode  13082
# sync Episode  13311
# Episode 13500 Epsilon 0.5092242081911829
# sync Episode  13530
# sync Episode  13746
# sync Episode  13943
# Episode 14000 Epsilon 0.49665110727625406
# sync Episode  14143
# sync Episode  14352
# Episode 14500 Epsilon 0.4843884449934142
# sync Episode  14558
# sync Episode  14742
# Best rewards so far: 665.0
# sync Episode  14923
# Episode 15000 Epsilon 0.472428556396287
# sync Episode  15121
# sync Episode  15302
# sync Episode  15492
# Episode 15500 Epsilon 0.46076396579136825
# sync Episode  15683
# Best rewards so far: 871.0
# sync Episode  15865
# Episode 16000 Epsilon 0.44938738206524204
# sync Episode  16055
# Best rewards so far: 985.0
# sync Episode  16236
# sync Episode  16413
# Episode 16500 Epsilon 0.4382916941271688
# sync Episode  16590
# sync Episode  16772
# sync Episode  16951
# Episode 17000 Epsilon 0.42746996646420016
# sync Episode  17127
# sync Episode  17291
# sync Episode  17459
# Episode 17500 Epsilon 0.4169154348060405
# sync Episode  17616
# sync Episode  17783
# sync Episode  17949
# Episode 18000 Epsilon 0.40662150189694446
# sync Episode  18104
# sync Episode  18259
# sync Episode  18411
# Episode 18500 Epsilon 0.39658173337201497
# sync Episode  18565
# sync Episode  18723
# sync Episode  18874
# Episode 19000 Epsilon 0.3867898537353129
# sync Episode  19026
# sync Episode  19176
# sync Episode  19327
# sync Episode  19474
# Episode 19500 Epsilon 0.37723974243726904
# sync Episode  19624
# sync Episode  19767
# sync Episode  19907
# Episode 20000 Epsilon 0.3679254300489543
# sync Episode  20046
# sync Episode  20187
# sync Episode  20330
# sync Episode  20479
# Episode 20500 Epsilon 0.35884109453080254
# sync Episode  20620
# sync Episode  20754
# sync Episode  20890
# Episode 21000 Epsilon 0.34998105759346765
# sync Episode  21031
# sync Episode  21168
# sync Episode  21312
# sync Episode  21452
# Episode 21500 Epsilon 0.341339781148527
# sync Episode  21591
# sync Episode  21730
# sync Episode  21869
# Episode 22000 Epsilon 0.33291186384682486
# sync Episode  22002
# sync Episode  22139
# sync Episode  22271
# sync Episode  22405
# Episode 22500 Epsilon 0.32469203770228455
# sync Episode  22533
# sync Episode  22655
# sync Episode  22779
# sync Episode  22900
# Episode 23000 Epsilon 0.3166751647990786
# sync Episode  23024
# sync Episode  23152
# sync Episode  23280
# sync Episode  23406
# Episode 23500 Epsilon 0.3088562340801069
# sync Episode  23528
# sync Episode  23652
# sync Episode  23772
# sync Episode  23894
# Episode 24000 Epsilon 0.3012303582147639
# sync Episode  24011
# sync Episode  24134
# sync Episode  24266
# sync Episode  24388
# Episode 24500 Epsilon 0.2937927705440459
# sync Episode  24507
# sync Episode  24624
# sync Episode  24736
# sync Episode  24850
# sync Episode  24975
# Episode 25000 Epsilon 0.28653882210108517
# sync Episode  25098
# sync Episode  25214
# sync Episode  25343
# sync Episode  25469
# Episode 25500 Epsilon 0.27946397870524836
# sync Episode  25584
# sync Episode  25700
# sync Episode  25821
# sync Episode  25938
# Episode 26000 Epsilon 0.2725638181279863
# sync Episode  26061
# sync Episode  26177
# sync Episode  26304
# sync Episode  26425
# Episode 26500 Epsilon 0.26583402732865635
# sync Episode  26544
# sync Episode  26667
# sync Episode  26786
# sync Episode  26910
# Episode 27000 Epsilon 0.2592703997585973
# sync Episode  27026
# sync Episode  27142
# sync Episode  27259
# sync Episode  27371
# sync Episode  27481
# Episode 27500 Epsilon 0.25286883273177047
# sync Episode  27599
# sync Episode  27711
# sync Episode  27831
# sync Episode  27957
# Episode 28000 Epsilon 0.24662532486031646
# sync Episode  28075
# sync Episode  28193
# sync Episode  28314
# sync Episode  28431
# Episode 28500 Epsilon 0.2405359735534331
# sync Episode  28549
# sync Episode  28662
# sync Episode  28781
# sync Episode  28900
# Episode 29000 Epsilon 0.23459697257800766
# sync Episode  29022
# sync Episode  29148
# sync Episode  29279
# sync Episode  29412
# Episode 29500 Epsilon 0.2288046096794772
# sync Episode  29540
# sync Episode  29672
# sync Episode  29807
# sync Episode  29945
# Episode 30000 Epsilon 0.22315526426143575
# sync Episode  30083
# sync Episode  30226
# sync Episode  30369
# Episode 30500 Epsilon 0.2176454051225255
# sync Episode  30513
# sync Episode  30657
# sync Episode  30805
# sync Episode  30957
# Episode 31000 Epsilon 0.2122715882492153
# sync Episode  31107
# sync Episode  31257
# sync Episode  31408
# Episode 31500 Epsilon 0.20703045466306944
# sync Episode  31562
# sync Episode  31715
# sync Episode  31875
# Episode 32000 Epsilon 0.20191872832117327
# sync Episode  32036
# sync Episode  32195
# sync Episode  32356
# Episode 32500 Epsilon 0.19693321406839684
# sync Episode  32521
# sync Episode  32684
# sync Episode  32848
# Episode 33000 Epsilon 0.1920707956402188
# sync Episode  33009
# sync Episode  33171
# sync Episode  33338
# Episode 33500 Epsilon 0.1873284337148642
# sync Episode  33507
# sync Episode  33681
# sync Episode  33855
# Episode 34000 Epsilon 0.18270316401353012
# sync Episode  34031
# sync Episode  34204
# sync Episode  34377
# Episode 34500 Epsilon 0.17819209544752743
# sync Episode  34553
# sync Episode  34736
# sync Episode  34915
# Episode 35000 Epsilon 0.1737924083111629
# sync Episode  35096
# sync Episode  35275
# sync Episode  35455
# Episode 35500 Epsilon 0.1695013525192428
# sync Episode  35639
# sync Episode  35823
# Episode 36000 Epsilon 0.1653162458880963
# sync Episode  36006
# sync Episode  36189
# sync Episode  36374
# Episode 36500 Epsilon 0.16123447245903783
# sync Episode  36558
# sync Episode  36746
# sync Episode  36936
# Episode 37000 Epsilon 0.1572534808632268
# sync Episode  37130
# sync Episode  37321
# Episode 37500 Epsilon 0.15337078272689875
# sync Episode  37514
# sync Episode  37708
# sync Episode  37903
# Episode 38000 Epsilon 0.14958395111597347
# sync Episode  38096
# sync Episode  38291
# sync Episode  38485
# Episode 38500 Epsilon 0.14589061901906616
# sync Episode  38681
# sync Episode  38879
# Episode 39000 Epsilon 0.1422884778679538
# sync Episode  39074
# sync Episode  39270
# sync Episode  39469
# Episode 39500 Epsilon 0.13877527609457405
# sync Episode  39664
# sync Episode  39859

# %%
mountaincar.test(10, 'carpole_dql_39000.pt')
