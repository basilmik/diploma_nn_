# %% [markdown]
# # imports

# %%
# !pip install gymnasium
# !pip install gymnasium[classic-control]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium in c:\users\basil\appdata\roaming\python\python39\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\program files (x86)\microsoft visual studio\shared\python39_64\lib\site-packages (from gymnasium) (1.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\program files (x86)\microsoft visual studio\shared\python39_64\lib\site-packages (from gymnasium) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\program files (x86)\microsoft visual studio\shared\python39_64\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[classic-control] in c:\users\basil\appdata\roaming\python\python39\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\program files (x86)\microsoft visual studio\shared\python39_64\lib\site-packages (from gymnasium[classic-control]) (1.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium[classic-control]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\program files (x86)\microsoft visual studio\shared\python39_64\lib\site-packages (from gymnasium[classic-control]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium[classic-control]) (7.1.0)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\basil\appdata\roaming\python\python39\site-packages (from gymnasium[classic-control]) (2.5.2)
# Requirement already satisfied: zipp>=0.5 in c:\program files (x86)\microsoft visual studio\shared\python39_64\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium[classic-control]) (3.17.0)

# %%
import numpy as np
import random
import gymnasium as gym
from collections import deque
from matplotlib import pyplot as plt
import copy

# %% [markdown]
# # classes for nn

# %% [markdown]
# ## actiovations and derivatives

# %%
def Sigmoid(x):
    res = 1 / (1 + np.exp(-x))
    return res

def d_Sigmoid(x):
    y = x * (1 - x)
    return y

def ReLU_my(x):
    x = np.maximum(0, x)
    return x
    
def d_ReLU_my(x): 
    x[x<=0] = 0
    x[x>0] = 1
    return x


def Linear(x):
    return x

def d_Linear(x):
    y = np.ones(shape=(x.shape), dtype = x.dtype)
    return y

activations_dict = {
'Sigmoid': [Sigmoid, d_Sigmoid],
'ReLU': [ReLU, d_ReLU], 
'Linear': [Linear, d_Linear]
}

# %% [markdown]
# ## layer

# %%
class layer:
    def __init__(s, lr = 0.1, prev_size = 2, my_size=2, activation_type = "Sigmoid"):
        s.lr = lr
        s.size = my_size
        s.prev_size = prev_size
        s.weights = np.random.random((prev_size, s.size))
        funcs = activations_dict.get(activation_type)
        s.activation_f = funcs[0]
        s.d_activation_f = funcs[1]


    def activate(s, x):
        return s.activation_f(x)
        
    def d_activate(s, x):
        return s.d_activation_f(x)  

    def forward(s, inputs):
        s.input = np.asarray(inputs)
        s.neurons = np.dot(s.input, s.weights)
        s.neurons_activated = s.activate(s.neurons)
        
        return s.neurons_activated

    def backprop(s, layer_error): # for output here layer_error = target_val - s.forward
        s.delta = layer_error * s.d_activate(s.neurons_activated)
        
        s.prev_layer_error = np.dot(s.delta, s.weights.T)
        return s.prev_layer_error
        
    def update_weights(s):
        s.input_t = s.input.T
        #print("input_t: ", input_t.shape)
        #print("delta: ", s.delta.shape)
        
        s.v = s.input_t.reshape((s.input_t.shape[0], 1))
        #print("v: ", v.shape)

        s.d = s.delta.reshape((1, s.delta.shape[0]))
        s.weights += s.lr * np.dot(s.v, s.d)
        
    def print_info(s):
        print("my size: ", s.size)
        print("w: ", s.weights, "\n")
        
    def print_pic(s):
        print_size = min(2, s.size)
        print("\n╻...\nv...")
        for i in range(print_size):
            #if (i == print_size/2 and print_size != s.size):
                #print ("--", s.size, "--\t", end='')
            print('O\t', end='')
        print ("--", format(s.size, ' 5d') , "--\t", end='')

    def add_neuron(s):     
        add_w = np.zeros(shape=(s.prev_size, 1), dtype=float) + 0.1
        s.weights = np.concatenate((s.weights, add_w.T))
        s.size+=1


class input_layer:
    def __init__(s, size):
        s.size = size
        s.values = np.zeros(shape=(size), dtype = float)

    def print_info(s):
        print("IN LAYER\nsize: ", s.size)
        print(s.values)

    def print_pic(s):
        print_size = min(2, s.size)

        for i in range(print_size):
            #if (i == print_size/2 and print_size != s.size):
                #print ("--", s.size, "--\t", end='')
                
            print("| |\t", end='')
        print("")
        for i in range(print_size):
            #if (i == print_size/2 and print_size != s.size):
                #print ("--", s.size, "--\t", end='')
            print(" v \t", end='')
        print("")
        for i in range(print_size):
            #if (i == print_size/2 and print_size != s.size):
                #print ("--", s.size, "--\t", end='')
            print(' @\t', end='')
        print ("--", format(s.size, ' 5d') , "--\t", end='')

    def forward(s, x):
        return x

# %% [markdown]
# ## NN

# %%
class plastic_nn:
    def __init__(s):
        s.layers = []
        s.n_of_layers = 0
        
        pass
        
    def deep_copy(s):
        return copy.deepcopy(s)

    def forward(s, data):
        for lay in layers:
            data = lay.forward(data)
        s.last_result = data
        return s.last_result
        
    
    def backprop(s, correct):
        err = correct-s.last_result

        for lay in reversed(layers[1:]):
            err = lay.backprop(err)

    def update_w(s):
        for lay in reversed(layers[1:]):
            lay.update_weights()

    def learn_one(s, in_data, target_data):
        pnn.forward(in_data)
        pnn.backprop(target_data)
        pnn.update_w()   
        
    def append_one(s, new_layer, check = False):
        if check and s.n_of_layers!=0:
            last_layer_size = s.layers[-1].size
            if last_layer_size != new_layer.prev_size:
                print("size not match, layer ", s.n_of_layers)
                return
        s.layers.append(new_layer)
        s.n_of_layers+=1
        pass

    def check_layers_sizes(s, check_layers):
        #print("CHECK")
        for i in range(1, len(check_layers)):
            #print(i)
            #print("check_layers[i-1].size ",check_layers[i-1].size)
            #print("check_layers[i].prev_size ",check_layers[i].prev_size)
            if (check_layers[i-1].size != check_layers[i].prev_size):
                print("error between ", i-1, "and ", i)
                return False
        return True
        
    def append(s, new_layers):
        test_layers = np.array([])
        if s.n_of_layers != 0:
            test_layers = s.layers[-1]
            
        test_layers = np.append(test_layers, new_layers)
                
        if (s.check_layers_sizes(test_layers)):
            for lay in new_layers:
                s.append_one(lay)

            print("added succesfully")
            return True
        else:
            print("ERROR adding layers, check info above")
            return False

    def print_info(s):
        print("Num of layers: ", s.n_of_layers)
        for cnt in range(s.n_of_layers):
            print("#", cnt)
            s.layers[cnt].print_info()
            print("")
    
    def print_pic(s):
        print("Num of layers: ", s.n_of_layers)
        cnt = 0
        for lay in s.layers:
            lay.print_pic()
            print("#", cnt, end='')
            cnt+=1
        print("\nOUT |#|\nOUT  v")

# %% [markdown]
# # memory

# %%
def cart_pole_action_to_human(val):
    if (val):
        return "right";
    else:
        return "left";

def cart_pole_state_to_human(val):
    return "Cart Position ", val[0], "Cart Velocity ", val[1], "Pole Angle ", val[2], "Pole Angular Velocity ", val[3]



class replay_memory:
    def __init__(s, maxlen):
        s.memory = deque([], maxlen=maxlen)

    def append(s, val):
        s.memory.append(val)
        
    def clear(s):
        s.memory.clear()

    def get_sample(s, sample_size):
        return random.sample(s.memory, sample_size)

    def __len__(s):
        return len(s.memory)

    #cur_state, action, next_state, reward, terminated
    def print(s):
        for m in s.memory:
            print("state: ", cart_pole_state_to_human(m[0]))
            print("action: ", cart_pole_action_to_human(m[1]))
            print("next state: ", cart_pole_state_to_human(m[2]))
            print("reward: ", m[3])
            print("termninated?: ", m[4])
            print("\n")

# %% [markdown]
# # env run

# %%
bar_len = 50

def display_bar(bar_len, idx, total):
    idx = int(idx*bar_len/total)
    #print(perc)
    print("[", "-"*idx, "*", "-"*(bar_len-idx-1), "]",end='')
    print("\r",end='')

class test_env():
    def __init__(s, env_name, render_mode = ''): 
        s.reward_discount = 0.99 #gamma
        
        s.brain = plastic_nn()
        
        s.render_mode = render_mode
        s.env = gym.make(env_name)#, render_mode="human")
    
        s.memory = replay_memory(maxlen=10000)
        s.explore_prob = 0.85 # epsilon
        s.explore_disc_rate = 0.05
        
    def set_brain_layers(s, layers):
        s.brain.append(layers)
        
    def close_env(s):
        s.env.close()
        
    def choose_action(s, state):
        if (random.random() < s.explore_prob): 
            action = s.env.action_space.sample() # explore
            s.explore_prob-=s.explore_disc_rate
        else:
            action = s.brain.forward(state).argmax().item()
            # this is where you would insert your policy
            #action = 1 # right
        return action

    def save_memory(s, prev_state, action, state, reward, terminated):
        s.memory.append((prev_state, action, state, reward, terminated)) 

    def run_one_game(s):
        max_reward = 0
        reward_sum = 0
        iteration = 0
        
        prev_state, info = s.env.reset() # seed=42
        prev_reward = 0
        
        terminated = False
        truncated = False
        while (not terminated and not truncated):
            iteration += 1
            
            action = s.choose_action(prev_state)
            
            state, reward, terminated, truncated, info = s.env.step(action) 

            if (terminated or truncated):
                if (iteration == 199):
                    reward = 5
                else:
                    reward = -5
                
            reward_sum += reward
            
            s.save_memory(prev_state, action, state, reward, terminated)
            
            prev_state = state
            
            
        return reward_sum

    def optimize(s):
        last_brain = s.brain.deep_copy()

        batch = s.memory.get_sample(3)
        s.memory.print()
        
        for state, action, new_state, reward, terminated in batch:
            if terminated: 
                target = reward
            else:
                expected = last_brain.forward(new_state).max()
                target = reward + s.reward_discount * expected
            
            cur_res = s.brain.forward(state)
        
            # Adjust the specific action to the target that was just calculated
            target_res = last_brain.forward(state)

            target_res[action] = target

            s.brain.backprop(target_res)
            
            s.brain.update_w()
        
        
    def train(s):
        epochs = 1
        games_in_epoch = 5
        s.memory.clear()

        mean_time_array=[]
        epochs_array=[]
        
        for e in range(epochs):
            display_bar(bar_len, e, epochs)
           
            max_rew = 0
            reward_sum = 0
            
            for g in range(games_in_epoch):
                #print("game: ", g, end='\r')
                
                total_reward = s.run_one_game()
                #max_rew=max(max_rew, total_reward)
                reward_sum+=total_reward
                
                if (len(s.memory) > 3):
                    #print("1")
                    #s.brain.print_info()
                    s.optimize()
                    #s.brain.print_info()
                    s.memory.clear()
                    
                    
            #print("mean reward: ", reward_sum/games_in_epoch)
            mean_val = reward_sum
            epochs_array.append(e)
            mean_time_array.append(mean_val)

        plt.figure()
        plt.scatter(epochs_array, mean_time_array)
        plt.xlabel('epochs_array')
        plt.ylabel('mean_time_array')
        plt.title("mean/epoch")

# %%
#np.random.seed(5)

num_of_inputs = 4
hidden1 = 24 #some indian youtuber used this
hidden2 = 24
out_n = 2

lr = 0.01


layers = [input_layer(num_of_inputs), 
          layer(lr = lr, prev_size = num_of_inputs, my_size=hidden1, activation_type="ReLU"), 
          layer(lr = lr, prev_size = hidden1, my_size=hidden2, activation_type="ReLU"), 
          layer(lr = lr, prev_size = hidden2, my_size=out_n, activation_type='Linear')] #, activation_type="ReLU")]


model = test_env('CartPole-v1')

model.set_brain_layers(layers)
#model.brain.print_info()

model.train()
model.close_env()
#model.brain.print_info()
print("done")
# Out:
# added succesfully
# state:  ('Cart Position ', -0.0055496735, 'Cart Velocity ', 0.046671394, 'Pole Angle ', 0.035362497, 'Pole Angular Velocity ', 0.012988892)
# action:  right
# next state:  ('Cart Position ', -0.0046162456, 'Cart Velocity ', 0.24126883, 'Pole Angle ', 0.035622273, 'Pole Angular Velocity ', -0.26833037)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.0046162456, 'Cart Velocity ', 0.24126883, 'Pole Angle ', 0.035622273, 'Pole Angular Velocity ', -0.26833037)
# action:  left
# next state:  ('Cart Position ', 0.00020913107, 'Cart Velocity ', 0.04565709, 'Pole Angle ', 0.030255668, 'Pole Angular Velocity ', 0.035371836)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.00020913107, 'Cart Velocity ', 0.04565709, 'Pole Angle ', 0.030255668, 'Pole Angular Velocity ', 0.035371836)
# action:  right
# next state:  ('Cart Position ', 0.0011222728, 'Cart Velocity ', 0.2403324, 'Pole Angle ', 0.030963104, 'Pole Angular Velocity ', -0.24761367)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0011222728, 'Cart Velocity ', 0.2403324, 'Pole Angle ', 0.030963104, 'Pole Angular Velocity ', -0.24761367)
# action:  left
# next state:  ('Cart Position ', 0.0059289206, 'Cart Velocity ', 0.044782236, 'Pole Angle ', 0.02601083, 'Pole Angular Velocity ', 0.05467267)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0059289206, 'Cart Velocity ', 0.044782236, 'Pole Angle ', 0.02601083, 'Pole Angular Velocity ', 0.05467267)
# action:  left
# next state:  ('Cart Position ', 0.0068245656, 'Cart Velocity ', -0.15070283, 'Pole Angle ', 0.027104285, 'Pole Angular Velocity ', 0.3554474)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0068245656, 'Cart Velocity ', -0.15070283, 'Pole Angle ', 0.027104285, 'Pole Angular Velocity ', 0.3554474)
# action:  right
# next state:  ('Cart Position ', 0.0038105089, 'Cart Velocity ', 0.044023473, 'Pole Angle ', 0.034213234, 'Pole Angular Velocity ', 0.07143292)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0038105089, 'Cart Velocity ', 0.044023473, 'Pole Angle ', 0.034213234, 'Pole Angular Velocity ', 0.07143292)
# action:  left
# next state:  ('Cart Position ', 0.004690978, 'Cart Velocity ', -0.15157184, 'Pole Angle ', 0.03564189, 'Pole Angular Velocity ', 0.37471092)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.004690978, 'Cart Velocity ', -0.15157184, 'Pole Angle ', 0.03564189, 'Pole Angular Velocity ', 0.37471092)
# action:  right
# next state:  ('Cart Position ', 0.0016595415, 'Cart Velocity ', 0.043026183, 'Pole Angle ', 0.04313611, 'Pole Angular Velocity ', 0.09347577)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0016595415, 'Cart Velocity ', 0.043026183, 'Pole Angle ', 0.04313611, 'Pole Angular Velocity ', 0.09347577)
# action:  left
# next state:  ('Cart Position ', 0.0025200653, 'Cart Velocity ', -0.15268664, 'Pole Angle ', 0.045005623, 'Pole Angular Velocity ', 0.39945)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0025200653, 'Cart Velocity ', -0.15268664, 'Pole Angle ', 0.045005623, 'Pole Angular Velocity ', 0.39945)
# action:  left
# next state:  ('Cart Position ', -0.0005336676, 'Cart Velocity ', -0.34841716, 'Pole Angle ', 0.052994624, 'Pole Angular Velocity ', 0.7059757)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.0005336676, 'Cart Velocity ', -0.34841716, 'Pole Angle ', 0.052994624, 'Pole Angular Velocity ', 0.7059757)
# action:  left
# next state:  ('Cart Position ', -0.007502011, 'Cart Velocity ', -0.5442318, 'Pole Angle ', 0.06711414, 'Pole Angular Velocity ', 1.0148584)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.007502011, 'Cart Velocity ', -0.5442318, 'Pole Angle ', 0.06711414, 'Pole Angular Velocity ', 1.0148584)
# action:  left
# next state:  ('Cart Position ', -0.018386647, 'Cart Velocity ', -0.74018145, 'Pole Angle ', 0.08741131, 'Pole Angular Velocity ', 1.327838)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.018386647, 'Cart Velocity ', -0.74018145, 'Pole Angle ', 0.08741131, 'Pole Angular Velocity ', 1.327838)
# action:  left
# next state:  ('Cart Position ', -0.033190276, 'Cart Velocity ', -0.9362911, 'Pole Angle ', 0.11396807, 'Pole Angular Velocity ', 1.6465455)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.033190276, 'Cart Velocity ', -0.9362911, 'Pole Angle ', 0.11396807, 'Pole Angular Velocity ', 1.6465455)
# action:  left
# next state:  ('Cart Position ', -0.0519161, 'Cart Velocity ', -1.1325469, 'Pole Angle ', 0.14689897, 'Pole Angular Velocity ', 1.9724536)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.0519161, 'Cart Velocity ', -1.1325469, 'Pole Angle ', 0.14689897, 'Pole Angular Velocity ', 1.9724536)
# action:  left
# next state:  ('Cart Position ', -0.074567035, 'Cart Velocity ', -1.3288821, 'Pole Angle ', 0.18634805, 'Pole Angular Velocity ', 2.3068175)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.074567035, 'Cart Velocity ', -1.3288821, 'Pole Angle ', 0.18634805, 'Pole Angular Velocity ', 2.3068175)
# action:  left
# next state:  ('Cart Position ', -0.10114468, 'Cart Velocity ', -1.5251603, 'Pole Angle ', 0.2324844, 'Pole Angular Velocity ', 2.6506076)
# reward:  -5
# termninated?:  True
#
#
# [0.94326492 0.93986925 0.89983312 0.91159877 0.91986709 0.90420489
#  0.90350432 0.90004248 0.89593403 0.8630366  0.87425899 0.93811638
#  0.90966072 0.9026345  0.84693123 0.91084074 0.84946638 0.89694819
#  0.92140154 0.90742704 0.84564367 0.89055895 0.85185304 0.90417034]
# [0.62779456 0.63941275 0.60750598 0.63920688 0.62388208 0.62966973
#  0.60740102 0.60413917 0.6228766  0.62072475 0.62589193 0.62454885
#  0.63811188 0.61496395 0.6064901  0.61836049 0.60834406 0.63654416
#  0.6402539  0.61962972 0.61357712 0.61375372 0.62909273 0.62591348]
# [0.75317069 0.76194725 0.71105155 0.75538287 0.73652342 0.74189249
#  0.71259169 0.70845107 0.73362417 0.72157852 0.73036977 0.74605621
#  0.75279765 0.72424542 0.69907764 0.72926426 0.70313206 0.75022671
#  0.75828703 0.72917121 0.71106399 0.71888881 0.73063652 0.73914521]
# state:  ('Cart Position ', -0.036189687, 'Cart Velocity ', -0.006057233, 'Pole Angle ', -0.014100513, 'Pole Angular Velocity ', -0.03327105)
# action:  right
# next state:  ('Cart Position ', -0.036310833, 'Cart Velocity ', 0.18926406, 'Pole Angle ', -0.014765935, 'Pole Angular Velocity ', -0.33036926)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.036310833, 'Cart Velocity ', 0.18926406, 'Pole Angle ', -0.014765935, 'Pole Angular Velocity ', -0.33036926)
# action:  left
# next state:  ('Cart Position ', -0.03252555, 'Cart Velocity ', -0.005644623, 'Pole Angle ', -0.02137332, 'Pole Angular Velocity ', -0.042379152)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.03252555, 'Cart Velocity ', -0.005644623, 'Pole Angle ', -0.02137332, 'Pole Angular Velocity ', -0.042379152)
# action:  left
# next state:  ('Cart Position ', -0.032638445, 'Cart Velocity ', -0.20045367, 'Pole Angle ', -0.022220902, 'Pole Angular Velocity ', 0.2434844)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.032638445, 'Cart Velocity ', -0.20045367, 'Pole Angle ', -0.022220902, 'Pole Angular Velocity ', 0.2434844)
# action:  left
# next state:  ('Cart Position ', -0.036647517, 'Cart Velocity ', -0.3952513, 'Pole Angle ', -0.017351216, 'Pole Angular Velocity ', 0.5290763)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.036647517, 'Cart Velocity ', -0.3952513, 'Pole Angle ', -0.017351216, 'Pole Angular Velocity ', 0.5290763)
# action:  left
# next state:  ('Cart Position ', -0.044552542, 'Cart Velocity ', -0.5901249, 'Pole Angle ', -0.0067696893, 'Pole Angular Velocity ', 0.8162417)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.044552542, 'Cart Velocity ', -0.5901249, 'Pole Angle ', -0.0067696893, 'Pole Angular Velocity ', 0.8162417)
# action:  right
# next state:  ('Cart Position ', -0.05635504, 'Cart Velocity ', -0.39491093, 'Pole Angle ', 0.009555144, 'Pole Angular Velocity ', 0.52143717)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.05635504, 'Cart Velocity ', -0.39491093, 'Pole Angle ', 0.009555144, 'Pole Angular Velocity ', 0.52143717)
# action:  right
# next state:  ('Cart Position ', -0.06425326, 'Cart Velocity ', -0.19992477, 'Pole Angle ', 0.019983888, 'Pole Angular Velocity ', 0.23178045)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.06425326, 'Cart Velocity ', -0.19992477, 'Pole Angle ', 0.019983888, 'Pole Angular Velocity ', 0.23178045)
# action:  left
# next state:  ('Cart Position ', -0.06825175, 'Cart Velocity ', -0.39532647, 'Pole Angle ', 0.024619497, 'Pole Angular Velocity ', 0.5306994)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.06825175, 'Cart Velocity ', -0.39532647, 'Pole Angle ', 0.024619497, 'Pole Angular Velocity ', 0.5306994)
# action:  left
# next state:  ('Cart Position ', -0.076158285, 'Cart Velocity ', -0.5907859, 'Pole Angle ', 0.035233483, 'Pole Angular Velocity ', 0.8310371)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.076158285, 'Cart Velocity ', -0.5907859, 'Pole Angle ', 0.035233483, 'Pole Angular Velocity ', 0.8310371)
# action:  left
# next state:  ('Cart Position ', -0.087974004, 'Cart Velocity ', -0.7863713, 'Pole Angle ', 0.051854227, 'Pole Angular Velocity ', 1.1345896)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.087974004, 'Cart Velocity ', -0.7863713, 'Pole Angle ', 0.051854227, 'Pole Angular Velocity ', 1.1345896)
# action:  left
# next state:  ('Cart Position ', -0.10370143, 'Cart Velocity ', -0.98213196, 'Pole Angle ', 0.07454602, 'Pole Angular Velocity ', 1.4430742)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.10370143, 'Cart Velocity ', -0.98213196, 'Pole Angle ', 0.07454602, 'Pole Angular Velocity ', 1.4430742)
# action:  left
# next state:  ('Cart Position ', -0.12334407, 'Cart Velocity ', -1.1780882, 'Pole Angle ', 0.1034075, 'Pole Angular Velocity ', 1.7580885)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.12334407, 'Cart Velocity ', -1.1780882, 'Pole Angle ', 0.1034075, 'Pole Angular Velocity ', 1.7580885)
# action:  left
# next state:  ('Cart Position ', -0.14690584, 'Cart Velocity ', -1.3742185, 'Pole Angle ', 0.13856927, 'Pole Angular Velocity ', 2.08106)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.14690584, 'Cart Velocity ', -1.3742185, 'Pole Angle ', 0.13856927, 'Pole Angular Velocity ', 2.08106)
# action:  right
# next state:  ('Cart Position ', -0.1743902, 'Cart Velocity ', -1.180745, 'Pole Angle ', 0.18019047, 'Pole Angular Velocity ', 1.8342406)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.1743902, 'Cart Velocity ', -1.180745, 'Pole Angle ', 0.18019047, 'Pole Angular Velocity ', 1.8342406)
# action:  left
# next state:  ('Cart Position ', -0.1980051, 'Cart Velocity ', -1.3773452, 'Pole Angle ', 0.21687528, 'Pole Angular Velocity ', 2.1770563)
# reward:  -5
# termninated?:  True
#
#
# [0.96550384 0.95838529 0.92645412 0.89820624 0.94098324 0.89767178
#  0.93375936 0.92912306 0.88586361 0.82409597 0.83452506 0.9609533
#  0.8978582  0.91595093 0.82601591 0.92976179 0.82476563 0.85976073
#  0.92277773 0.92306193 0.78378178 0.89789233 0.76546976 0.89650028]
# [0.99285074 0.99181328 0.97860576 0.97196855 0.98576498 0.96999979
#  0.98158753 0.9791018  0.96317177 0.93349892 0.93945431 0.99143861
#  0.97175559 0.9751104  0.92896237 0.98112568 0.92897399 0.95422536
#  0.98121205 0.97886214 0.90376106 0.96733742 0.90206469 0.96825185]
# [0.98877471 0.9868051  0.96900272 0.95570544 0.97654755 0.95587297
#  0.97242567 0.97030399 0.94652856 0.8989676  0.91794546 0.98681111
#  0.95833389 0.9613133  0.90271655 0.97062061 0.89811298 0.93487058
#  0.96946539 0.96745657 0.86420392 0.95336673 0.85801031 0.9521449 ]
# state:  ('Cart Position ', 0.00024348161, 'Cart Velocity ', 0.031106092, 'Pole Angle ', 0.018518288, 'Pole Angular Velocity ', -0.021075962)
# action:  right
# next state:  ('Cart Position ', 0.00086560345, 'Cart Velocity ', 0.22595765, 'Pole Angle ', 0.01809677, 'Pole Angular Velocity ', -0.30785912)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.00086560345, 'Cart Velocity ', 0.22595765, 'Pole Angle ', 0.01809677, 'Pole Angular Velocity ', -0.30785912)
# action:  right
# next state:  ('Cart Position ', 0.0053847563, 'Cart Velocity ', 0.4208171, 'Pole Angle ', 0.011939586, 'Pole Angular Velocity ', -0.5947803)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0053847563, 'Cart Velocity ', 0.4208171, 'Pole Angle ', 0.011939586, 'Pole Angular Velocity ', -0.5947803)
# action:  right
# next state:  ('Cart Position ', 0.013801099, 'Cart Velocity ', 0.6157699, 'Pole Angle ', 4.3980126e-05, 'Pole Angular Velocity ', -0.88367856)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.013801099, 'Cart Velocity ', 0.6157699, 'Pole Angle ', 4.3980126e-05, 'Pole Angular Velocity ', -0.88367856)
# action:  right
# next state:  ('Cart Position ', 0.026116498, 'Cart Velocity ', 0.8108913, 'Pole Angle ', -0.01762959, 'Pole Angular Velocity ', -1.1763476)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.026116498, 'Cart Velocity ', 0.8108913, 'Pole Angle ', -0.01762959, 'Pole Angular Velocity ', -1.1763476)
# action:  right
# next state:  ('Cart Position ', 0.042334322, 'Cart Velocity ', 1.0062377, 'Pole Angle ', -0.041156545, 'Pole Angular Velocity ', -1.4745047)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.042334322, 'Cart Velocity ', 1.0062377, 'Pole Angle ', -0.041156545, 'Pole Angular Velocity ', -1.4745047)
# action:  right
# next state:  ('Cart Position ', 0.062459078, 'Cart Velocity ', 1.2018378, 'Pole Angle ', -0.070646636, 'Pole Angular Velocity ', -1.7797529)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.062459078, 'Cart Velocity ', 1.2018378, 'Pole Angle ', -0.070646636, 'Pole Angular Velocity ', -1.7797529)
# action:  right
# next state:  ('Cart Position ', 0.08649584, 'Cart Velocity ', 1.39768, 'Pole Angle ', -0.106241696, 'Pole Angular Velocity ', -2.0935364)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.08649584, 'Cart Velocity ', 1.39768, 'Pole Angle ', -0.106241696, 'Pole Angular Velocity ', -2.0935364)
# action:  right
# next state:  ('Cart Position ', 0.114449434, 'Cart Velocity ', 1.5936995, 'Pole Angle ', -0.14811242, 'Pole Angular Velocity ', -2.417084)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.114449434, 'Cart Velocity ', 1.5936995, 'Pole Angle ', -0.14811242, 'Pole Angular Velocity ', -2.417084)
# action:  right
# next state:  ('Cart Position ', 0.14632343, 'Cart Velocity ', 1.7897611, 'Pole Angle ', -0.1964541, 'Pole Angular Velocity ', -2.7513425)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.14632343, 'Cart Velocity ', 1.7897611, 'Pole Angle ', -0.1964541, 'Pole Angular Velocity ', -2.7513425)
# action:  left
# next state:  ('Cart Position ', 0.18211865, 'Cart Velocity ', 1.5964819, 'Pole Angle ', -0.25148094, 'Pole Angular Velocity ', -2.5243871)
# reward:  -5
# termninated?:  True
#
#
# [0.1526368  0.17352765 0.21665142 0.26022458 0.20441469 0.25450991
#  0.21006236 0.21128285 0.26491459 0.33359087 0.31254217 0.16020869
#  0.25570384 0.23422045 0.32271082 0.21717056 0.32729158 0.29142277
#  0.23279209 0.22616105 0.35417511 0.25233748 0.37775775 0.2542215 ]
# [0.04326812 0.05225225 0.08616338 0.1163652  0.0740141  0.11367349
#  0.08135376 0.08341476 0.12632379 0.1974777  0.17182426 0.04741856
#  0.11219176 0.10027013 0.18885194 0.08519172 0.19466323 0.14788948
#  0.09257144 0.09156923 0.2280165  0.11553531 0.24959775 0.11569749]
# [0.00889809 0.01104886 0.02578478 0.03770419 0.01944594 0.03747669
#  0.02356916 0.02499571 0.04559955 0.09103588 0.07223438 0.01025326
#  0.03575979 0.03228325 0.08722631 0.02464952 0.09200203 0.05588488
#  0.02617575 0.0274046  0.11939118 0.03993248 0.1302146  0.03935099]
# state:  ('Cart Position ', 0.004078847, 'Cart Velocity ', 0.038809586, 'Pole Angle ', -0.017507039, 'Pole Angular Velocity ', -0.031278785)
# action:  right
# next state:  ('Cart Position ', 0.0048550386, 'Cart Velocity ', 0.23417817, 'Pole Angle ', -0.018132616, 'Pole Angular Velocity ', -0.32943356)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.0048550386, 'Cart Velocity ', 0.23417817, 'Pole Angle ', -0.018132616, 'Pole Angular Velocity ', -0.32943356)
# action:  right
# next state:  ('Cart Position ', 0.009538602, 'Cart Velocity ', 0.42955348, 'Pole Angle ', -0.024721287, 'Pole Angular Velocity ', -0.62777907)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.009538602, 'Cart Velocity ', 0.42955348, 'Pole Angle ', -0.024721287, 'Pole Angular Velocity ', -0.62777907)
# action:  right
# next state:  ('Cart Position ', 0.018129671, 'Cart Velocity ', 0.62501156, 'Pole Angle ', -0.037276868, 'Pole Angular Velocity ', -0.9281439)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.018129671, 'Cart Velocity ', 0.62501156, 'Pole Angle ', -0.037276868, 'Pole Angular Velocity ', -0.9281439)
# action:  right
# next state:  ('Cart Position ', 0.030629903, 'Cart Velocity ', 0.8206164, 'Pole Angle ', -0.055839747, 'Pole Angular Velocity ', -1.2323042)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.030629903, 'Cart Velocity ', 0.8206164, 'Pole Angle ', -0.055839747, 'Pole Angular Velocity ', -1.2323042)
# action:  right
# next state:  ('Cart Position ', 0.047042232, 'Cart Velocity ', 1.0164102, 'Pole Angle ', -0.08048583, 'Pole Angular Velocity ', -1.5419456)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.047042232, 'Cart Velocity ', 1.0164102, 'Pole Angle ', -0.08048583, 'Pole Angular Velocity ', -1.5419456)
# action:  right
# next state:  ('Cart Position ', 0.06737044, 'Cart Velocity ', 1.2124023, 'Pole Angle ', -0.11132474, 'Pole Angular Velocity ', -1.8586192)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.06737044, 'Cart Velocity ', 1.2124023, 'Pole Angle ', -0.11132474, 'Pole Angular Velocity ', -1.8586192)
# action:  right
# next state:  ('Cart Position ', 0.091618486, 'Cart Velocity ', 1.4085561, 'Pole Angle ', -0.14849713, 'Pole Angular Velocity ', -2.1836905)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.091618486, 'Cart Velocity ', 1.4085561, 'Pole Angle ', -0.14849713, 'Pole Angular Velocity ', -2.1836905)
# action:  right
# next state:  ('Cart Position ', 0.11978961, 'Cart Velocity ', 1.604774, 'Pole Angle ', -0.19217093, 'Pole Angular Velocity ', -2.518276)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.11978961, 'Cart Velocity ', 1.604774, 'Pole Angle ', -0.19217093, 'Pole Angular Velocity ', -2.518276)
# action:  right
# next state:  ('Cart Position ', 0.15188509, 'Cart Velocity ', 1.8008795, 'Pole Angle ', -0.24253646, 'Pole Angular Velocity ', -2.8631706)
# reward:  -5
# termninated?:  True
#
#
# [0.02405087 0.02811481 0.05378938 0.06800128 0.04294826 0.06863483
#  0.05087367 0.05305384 0.07969153 0.13191166 0.11083367 0.02658451
#  0.06587795 0.0625917  0.12974713 0.05145467 0.13530981 0.09039914
#  0.05251529 0.05548614 0.16017469 0.07341729 0.16830821 0.070621  ]
# [0.10262175 0.11359562 0.15787759 0.18305377 0.14131326 0.18287617
#  0.15372978 0.15656462 0.19708616 0.25736148 0.235479   0.10785515
#  0.18018026 0.17215022 0.25273221 0.155413   0.25924585 0.21241079
#  0.15994075 0.16205931 0.28256525 0.18768673 0.29340588 0.18437763]
# [0.01002199 0.01194778 0.02759762 0.03597756 0.0204788  0.03686177
#  0.02561421 0.02723504 0.04489349 0.08465526 0.0678271  0.01139696
#  0.03480303 0.03315757 0.08353441 0.02574754 0.08854704 0.05185037
#  0.02590865 0.02836368 0.11045457 0.04042291 0.11460881 0.03832044]
# state:  ('Cart Position ', -0.012228898, 'Cart Velocity ', 0.042070005, 'Pole Angle ', 0.004756611, 'Pole Angular Velocity ', -0.0035410994)
# action:  left
# next state:  ('Cart Position ', -0.011387497, 'Cart Velocity ', -0.15311985, 'Pole Angle ', 0.004685789, 'Pole Angular Velocity ', 0.2906388)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.011387497, 'Cart Velocity ', -0.15311985, 'Pole Angle ', 0.004685789, 'Pole Angular Velocity ', 0.2906388)
# action:  right
# next state:  ('Cart Position ', -0.014449894, 'Cart Velocity ', 0.041934982, 'Pole Angle ', 0.010498565, 'Pole Angular Velocity ', -0.0005626145)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.014449894, 'Cart Velocity ', 0.041934982, 'Pole Angle ', 0.010498565, 'Pole Angular Velocity ', -0.0005626145)
# action:  right
# next state:  ('Cart Position ', -0.013611195, 'Cart Velocity ', 0.23690481, 'Pole Angle ', 0.010487312, 'Pole Angular Velocity ', -0.28991473)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.013611195, 'Cart Velocity ', 0.23690481, 'Pole Angle ', 0.010487312, 'Pole Angular Velocity ', -0.28991473)
# action:  right
# next state:  ('Cart Position ', -0.0088730985, 'Cart Velocity ', 0.43187565, 'Pole Angle ', 0.004689018, 'Pole Angular Velocity ', -0.5792717)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.0088730985, 'Cart Velocity ', 0.43187565, 'Pole Angle ', 0.004689018, 'Pole Angular Velocity ', -0.5792717)
# action:  right
# next state:  ('Cart Position ', -0.00023558529, 'Cart Velocity ', 0.6269316, 'Pole Angle ', -0.0068964157, 'Pole Angular Velocity ', -0.8704738)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', -0.00023558529, 'Cart Velocity ', 0.6269316, 'Pole Angle ', -0.0068964157, 'Pole Angular Velocity ', -0.8704738)
# action:  right
# next state:  ('Cart Position ', 0.012303046, 'Cart Velocity ', 0.82214665, 'Pole Angle ', -0.024305891, 'Pole Angular Velocity ', -1.1653169)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.012303046, 'Cart Velocity ', 0.82214665, 'Pole Angle ', -0.024305891, 'Pole Angular Velocity ', -1.1653169)
# action:  right
# next state:  ('Cart Position ', 0.02874598, 'Cart Velocity ', 1.0175765, 'Pole Angle ', -0.04761223, 'Pole Angular Velocity ', -1.4655203)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.02874598, 'Cart Velocity ', 1.0175765, 'Pole Angle ', -0.04761223, 'Pole Angular Velocity ', -1.4655203)
# action:  right
# next state:  ('Cart Position ', 0.04909751, 'Cart Velocity ', 1.213248, 'Pole Angle ', -0.07692263, 'Pole Angular Velocity ', -1.7726877)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.04909751, 'Cart Velocity ', 1.213248, 'Pole Angle ', -0.07692263, 'Pole Angular Velocity ', -1.7726877)
# action:  right
# next state:  ('Cart Position ', 0.07336247, 'Cart Velocity ', 1.4091486, 'Pole Angle ', -0.11237639, 'Pole Angular Velocity ', -2.0882626)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.07336247, 'Cart Velocity ', 1.4091486, 'Pole Angle ', -0.11237639, 'Pole Angular Velocity ', -2.0882626)
# action:  right
# next state:  ('Cart Position ', 0.10154544, 'Cart Velocity ', 1.6052111, 'Pole Angle ', -0.15414163, 'Pole Angular Velocity ', -2.4134705)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.10154544, 'Cart Velocity ', 1.6052111, 'Pole Angle ', -0.15414163, 'Pole Angular Velocity ', -2.4134705)
# action:  right
# next state:  ('Cart Position ', 0.13364966, 'Cart Velocity ', 1.8012981, 'Pole Angle ', -0.20241106, 'Pole Angular Velocity ', -2.749252)
# reward:  1.0
# termninated?:  False
#
#
# state:  ('Cart Position ', 0.13364966, 'Cart Velocity ', 1.8012981, 'Pole Angle ', -0.20241106, 'Pole Angular Velocity ', -2.749252)
# action:  right
# next state:  ('Cart Position ', 0.16967562, 'Cart Velocity ', 1.9971826, 'Pole Angle ', -0.2573961, 'Pole Angular Velocity ', -3.0961838)
# reward:  -5
# termninated?:  True
#
#
# [0.55401739 0.55787187 0.54076708 0.55916744 0.54830119 0.55397948
#  0.54461817 0.542067   0.55332846 0.55234486 0.55308514 0.54804139
#  0.55729777 0.54855    0.54422317 0.54944027 0.54709083 0.55948187
#  0.56035407 0.54836979 0.54743025 0.54815902 0.55766699 0.55267977]
# [0.07828555 0.09219367 0.13155117 0.17122055 0.11784373 0.16774252
#  0.12751071 0.12954727 0.18250433 0.25662939 0.23131196 0.08251194
#  0.16775708 0.1500118  0.24361348 0.13211277 0.25364091 0.20654765
#  0.14436414 0.14001143 0.28492235 0.16776678 0.30742578 0.16748456]
# [0.00755887 0.00946065 0.02246089 0.03351283 0.01663295 0.0336657
#  0.02073042 0.02213224 0.04179888 0.08500168 0.06711156 0.0085883
#  0.03230014 0.02860246 0.08003828 0.02145858 0.08706748 0.05092437
#  0.02306033 0.02406951 0.11386704 0.03569858 0.12228838 0.03477619]
# done

# %%
model.close_env()

# %%
model.env = gym.make('CartPole-v1', render_mode="human")
# print(env.action_space) # 0 or 1

state, info = model.env.reset(seed=42)
for _ in range(100):
   action = model.brain.forward(state).argmax().item()
   state, reward, terminated, truncated, info = model.env.step(action)

   if terminated or truncated:
      observation, info = model.env.reset()

model.env.close()

# %%
# test1nn = plastic_nn()
# layers = [input_layer(2), 
          
#           layer(lr = lr, prev_size = 2, my_size=1), 
#           layer(lr = lr, prev_size = 1, my_size=1)]

# test1nn.append(layers)
# test1nn.print_info()

# test2nn = test1nn.deep_copy()
# test2nn.print_info()
# test2nn.append([layer(lr = lr, prev_size = 1, my_size=2)])
# test2nn.print_info()
# test1nn.print_info()
